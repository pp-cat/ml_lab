# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import random
from sklearn.tree import DecisionTreeClassifier, export_graphviz

# %%
adult_tmp = pd.read_csv("D:\\wb\\python\\ML\\adult\\adult_with_heading.csv")

# %%
adult_tmp.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'class'],
#       dtype='object')

# %%
adult_tmp['cap-gain-loss'] = adult_tmp['capital-gain'] + adult_tmp ['capital-loss']

# %%
adult_tmp.loc[:,'marital-status'] = adult_tmp['marital-status'].str.lstrip()  # column has prefix space

# %%
adult_tmp
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# 3      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4      Married-civ-spouse      Prof-specialty            Wife   Black
# ...                   ...                 ...             ...     ...
# 32556  Married-civ-spouse        Tech-support            Wife   White
# 32557  Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558             Widowed        Adm-clerical       Unmarried   White
# 32559       Never-married        Adm-clerical       Own-child   White
# 32560  Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#         class  cap-gain-loss
# 0       <=50K           2174
# 1       <=50K              0
# 2       <=50K              0
# 3       <=50K              0
# 4       <=50K              0
# ...       ...            ...
# 32556   <=50K              0
# 32557    >50K              0
# 32558   <=50K              0
# 32559   <=50K              0
# 32560    >50K          15024
#
# [32561 rows x 16 columns]

# %% [markdown]
# ### Code for Partition the data

# %%
adult_train, adult_test = train_test_split(adult_tmp, test_size= 0.25, random_state = 7)

# %%
adult_tmp.shape
# Out:
# (32561, 16)

# %%
adult_train.shape
# Out:
# (24420, 16)

# %%
adult_test.shape
# Out:
# (8141, 16)

# %% [markdown]
# ### randomly partition
#
# Notes the "index" columns, they are randomly arranged !!
# So be careful when manipulates dataFrame !!
# It is because the index are not sequencial alignment when add, concate..etc with other dataFrame !!

# %%
adult_train.head(20)
# Out:
#        age     workclass  fnlwgt      education  education-num  \
# 22659   22       Private   34616   Some-college             10
# 25090   31       Private   91666        HS-grad              9
# 18617   25       Private  193773        HS-grad              9
# 8482    26       Private  247025        HS-grad              9
# 1544    69             ?  473040        5th-6th              3
# 10515   48   Federal-gov  147397        HS-grad              9
# 12544   43     Local-gov  186995        HS-grad              9
# 28519   39   Federal-gov  376455    Prof-school             15
# 1589    23       Private  121471      Bachelors             13
# 27680   38       Private  105150      Bachelors             13
# 15545   53       Private  260106        HS-grad              9
# 31793   59             ?  147989        HS-grad              9
# 15922   23       Private  201680           12th              8
# 7435    27       Private  107218        HS-grad              9
# 15116   60       Private   74243      Assoc-voc             11
# 7417    23       Private  273206      Bachelors             13
# 24249   31       Private   19491   Some-college             10
# 10337   54       Private  311020        HS-grad              9
# 7872    81             ?  162882        HS-grad              9
# 10758   63       Private  236338        HS-grad              9
#
#            marital-status        occupation    relationship  \
# 22659       Never-married             Sales   Not-in-family
# 25090       Never-married   Exec-managerial       Own-child
# 18617       Never-married     Other-service   Not-in-family
# 8482        Never-married   Protective-serv       Unmarried
# 1544             Divorced                 ?   Not-in-family
# 10515  Married-civ-spouse      Adm-clerical         Husband
# 12544            Divorced   Protective-serv       Unmarried
# 28519  Married-civ-spouse    Prof-specialty         Husband
# 1589        Never-married      Adm-clerical   Not-in-family
# 27680  Married-civ-spouse    Prof-specialty         Husband
# 15545             Widowed             Sales   Not-in-family
# 31793             Widowed                 ?   Not-in-family
# 15922  Married-civ-spouse      Craft-repair         Husband
# 7435        Never-married     Other-service       Own-child
# 15116             Widowed      Craft-repair   Not-in-family
# 7417        Never-married      Adm-clerical   Not-in-family
# 24249       Never-married      Craft-repair   Not-in-family
# 10337  Married-civ-spouse     Other-service         Husband
# 7872             Divorced                 ?   Not-in-family
# 10758  Married-civ-spouse             Sales            Wife
#
#                       race      sex  capital-gain  capital-loss  \
# 22659                White   Female             0             0
# 25090                White     Male             0             0
# 18617                Black   Female             0             0
# 8482                 White     Male             0             0
# 1544                 White     Male             0             0
# 10515                White     Male             0             0
# 12544                White   Female             0             0
# 28519                White     Male             0          1887
# 1589                 White   Female             0             0
# 27680                White     Male             0             0
# 15545                White   Female             0             0
# 31793                White   Female             0             0
# 15922                White     Male             0             0
# 7435    Asian-Pac-Islander     Male             0             0
# 15116                White   Female             0             0
# 7417                 White   Female             0             0
# 24249                White     Male             0             0
# 10337                White     Male             0             0
# 7872                 White   Female             0             0
# 10758                White   Female             0             0
#
#        hours-per-week  native-country   class  cap-gain-loss
# 22659              30   United-States   <=50K              0
# 25090              60   United-States   <=50K              0
# 18617              35   United-States   <=50K              0
# 8482               44   United-States   <=50K              0
# 1544               40   United-States   <=50K              0
# 10515              36   United-States   <=50K              0
# 12544              40   United-States   <=50K              0
# 28519              50   United-States    >50K           1887
# 1589               40   United-States   <=50K              0
# 27680              45   United-States    >50K              0
# 15545              30   United-States   <=50K              0
# 31793              35   United-States   <=50K              0
# 15922              40   United-States   <=50K              0
# 7435               40   United-States   <=50K              0
# 15116              30   United-States   <=50K              0
# 7417               23   United-States   <=50K              0
# 24249              40   United-States   <=50K              0
# 10337              50   United-States   <=50K              0
# 7872               35   United-States   <=50K              0
# 10758              35   United-States   <=50K              0

# %% [markdown]
# Build CART Decision Tree

# %%
y = adult_train[['class']]

# %%
mar_cat = adult_train[['marital-status']]

# %%
mar_cat[['marital-status']]
# Out:
#            marital-status
# 22659       Never-married
# 25090       Never-married
# 18617       Never-married
# 8482        Never-married
# 1544             Divorced
# ...                   ...
# 5699        Never-married
# 10742  Married-civ-spouse
# 16921  Married-civ-spouse
# 25796  Married-civ-spouse
# 28847            Divorced
#
# [24420 rows x 1 columns]

# %%
# mar_cat.loc[:,'marital-status'] = mar_cat['marital-status'].str.lstrip()

# %%
mar_cat=mar_cat.replace({'Married-AF-spouse':'Married', 'Married-civ-spouse':'Married', 'Married-spouse-absent':'Married'})

# %%
mar_cat
# Out:
#       marital-status
# 22659  Never-married
# 25090  Never-married
# 18617  Never-married
# 8482   Never-married
# 1544        Divorced
# ...              ...
# 5699   Never-married
# 10742        Married
# 16921        Married
# 25796        Married
# 28847       Divorced
#
# [24420 rows x 1 columns]

# %%
dummies = pd.get_dummies(mar_cat['marital-status'], dtype='uint8')

# %%
dummies
# Out:
#        Divorced  Married  Never-married  Separated  Widowed
# 22659         0        0              1          0        0
# 25090         0        0              1          0        0
# 18617         0        0              1          0        0
# 8482          0        0              1          0        0
# 1544          1        0              0          0        0
# ...         ...      ...            ...        ...      ...
# 5699          0        0              1          0        0
# 10742         0        1              0          0        0
# 16921         0        1              0          0        0
# 25796         0        1              0          0        0
# 28847         1        0              0          0        0
#
# [24420 rows x 5 columns]

# %%
x = pd.concat((adult_train[['cap-gain-loss']], dummies), axis=1)
x
# Out:
#        cap-gain-loss  Divorced  Married  Never-married  Separated  Widowed
# 22659              0         0        0              1          0        0
# 25090              0         0        0              1          0        0
# 18617              0         0        0              1          0        0
# 8482               0         0        0              1          0        0
# 1544               0         1        0              0          0        0
# ...              ...       ...      ...            ...        ...      ...
# 5699               0         0        0              1          0        0
# 10742              0         0        1              0          0        0
# 16921              0         0        1              0          0        0
# 25796           2415         0        1              0          0        0
# 28847              0         1        0              0          0        0
#
# [24420 rows x 6 columns]

# %%
y_names=["<=50K", ">50K"]
x_names=["cap-gain-loss", "Divorced", "Married", "Never-married", "Separated",	"Widowed"]

# %%
cart01 = DecisionTreeClassifier(criterion = "gini", max_leaf_nodes=5).fit(x,y)

# %%
export_graphviz(cart01, out_file="D:\\wb\\python\\ML\\adult\\cart01.dot", feature_names=x_names, class_names=y_names)

# %% [markdown]
# ### test the model

# %%
predClass = cart01.predict(x)

# %%
type(predClass)
# Out:
# numpy.ndarray

# %% [markdown]
# #### the output of predict() is a np.array !!

# %%
predClass=pd.Series(predClass, name='predict').to_frame(name='predict')

# %% [markdown]
# ### we need to make index sequential (dataFrame x) first before concate the result !

# %%
predClass
# Out:
#       predict
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 24415   <=50K
# 24416   <=50K
# 24417   <=50K
# 24418    >50K
# 24419   <=50K
#
# [24420 rows x 1 columns]

# %%
x_copy=x.copy()
x_copy
# Out:
#        cap-gain-loss  Divorced  Married  Never-married  Separated  Widowed
# 22659              0         0        0              1          0        0
# 25090              0         0        0              1          0        0
# 18617              0         0        0              1          0        0
# 8482               0         0        0              1          0        0
# 1544               0         1        0              0          0        0
# ...              ...       ...      ...            ...        ...      ...
# 5699               0         0        0              1          0        0
# 10742              0         0        1              0          0        0
# 16921              0         0        1              0          0        0
# 25796           2415         0        1              0          0        0
# 28847              0         1        0              0          0        0
#
# [24420 rows x 6 columns]

# %%
x_copy=x_copy.reset_index()
x_copy
# Out:
#        index  cap-gain-loss  Divorced  Married  Never-married  Separated  \
# 0      22659              0         0        0              1          0
# 1      25090              0         0        0              1          0
# 2      18617              0         0        0              1          0
# 3       8482              0         0        0              1          0
# 4       1544              0         1        0              0          0
# ...      ...            ...       ...      ...            ...        ...
# 24415   5699              0         0        0              1          0
# 24416  10742              0         0        1              0          0
# 24417  16921              0         0        1              0          0
# 24418  25796           2415         0        1              0          0
# 24419  28847              0         1        0              0          0
#
#        Widowed
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 24415        0
# 24416        0
# 24417        0
# 24418        0
# 24419        0
#
# [24420 rows x 7 columns]

# %%
pd.concat((x_copy,predClass), axis=1).head(30)
# Out:
#     index  cap-gain-loss  Divorced  Married  Never-married  Separated  \
# 0   22659              0         0        0              1          0
# 1   25090              0         0        0              1          0
# 2   18617              0         0        0              1          0
# 3    8482              0         0        0              1          0
# 4    1544              0         1        0              0          0
# 5   10515              0         0        1              0          0
# 6   12544              0         1        0              0          0
# 7   28519           1887         0        1              0          0
# 8    1589              0         0        0              1          0
# 9   27680              0         0        1              0          0
# 10  15545              0         0        0              0          0
# 11  31793              0         0        0              0          0
# 12  15922              0         0        1              0          0
# 13   7435              0         0        0              1          0
# 14  15116              0         0        0              0          0
# 15   7417              0         0        0              1          0
# 16  24249              0         0        0              1          0
# 17  10337              0         0        1              0          0
# 18   7872              0         1        0              0          0
# 19  10758              0         0        1              0          0
# 20  24437              0         0        0              0          1
# 21  15798              0         0        0              1          0
# 22  14646              0         0        0              1          0
# 23  29034              0         0        0              1          0
# 24  11508              0         0        1              0          0
# 25  27089              0         0        0              1          0
# 26  32461              0         0        0              1          0
# 27   5398              0         1        0              0          0
# 28  28578              0         0        1              0          0
# 29  27943              0         0        0              1          0
#
#     Widowed predict
# 0         0   <=50K
# 1         0   <=50K
# 2         0   <=50K
# 3         0   <=50K
# 4         0   <=50K
# 5         0   <=50K
# 6         0   <=50K
# 7         0    >50K
# 8         0   <=50K
# 9         0   <=50K
# 10        1   <=50K
# 11        1   <=50K
# 12        0   <=50K
# 13        0   <=50K
# 14        1   <=50K
# 15        0   <=50K
# 16        0   <=50K
# 17        0   <=50K
# 18        0   <=50K
# 19        0   <=50K
# 20        0   <=50K
# 21        0   <=50K
# 22        0   <=50K
# 23        0   <=50K
# 24        0   <=50K
# 25        0   <=50K
# 26        0   <=50K
# 27        0   <=50K
# 28        0   <=50K
# 29        0   <=50K

# %%
def dummies(src):
	# convert categories to dummies variable
	src = src.replace({'Married-AF-spouse':'Married', 'Married-civ-spouse':'Married', 'Married-spouse-absent':'Married'})
	return pd.get_dummies(src, dtype='uint8')

# %%
tmp= dummies(mar_cat['marital-status'])

# %%
tmp
# Out:
#        Divorced  Married  Never-married  Separated  Widowed
# 22659         0        0              1          0        0
# 25090         0        0              1          0        0
# 18617         0        0              1          0        0
# 8482          0        0              1          0        0
# 1544          1        0              0          0        0
# ...         ...      ...            ...        ...      ...
# 5699          0        0              1          0        0
# 10742         0        1              0          0        0
# 16921         0        1              0          0        0
# 25796         0        1              0          0        0
# 28847         1        0              0          0        0
#
# [24420 rows x 5 columns]

# %%
pd.concat((adult_train[['cap-gain-loss']], dummies(mar_cat['marital-status'])), axis=1)
# Out:
#        cap-gain-loss  Divorced  Married  Never-married  Separated  Widowed
# 22659              0         0        0              1          0        0
# 25090              0         0        0              1          0        0
# 18617              0         0        0              1          0        0
# 8482               0         0        0              1          0        0
# 1544               0         1        0              0          0        0
# ...              ...       ...      ...            ...        ...      ...
# 5699               0         0        0              1          0        0
# 10742              0         0        1              0          0        0
# 16921              0         0        1              0          0        0
# 25796           2415         0        1              0          0        0
# 28847              0         1        0              0          0        0
#
# [24420 rows x 6 columns]

# %%
pd.concat((adult_train[['cap-gain-loss']], dummies(adult_train[['marital-status']])), axis=1)
# Out:
#        cap-gain-loss  marital-status_Divorced  marital-status_Married  \
# 22659              0                        0                       0
# 25090              0                        0                       0
# 18617              0                        0                       0
# 8482               0                        0                       0
# 1544               0                        1                       0
# ...              ...                      ...                     ...
# 5699               0                        0                       0
# 10742              0                        0                       1
# 16921              0                        0                       1
# 25796           2415                        0                       1
# 28847              0                        1                       0
#
#        marital-status_Never-married  marital-status_Separated  \
# 22659                             1                         0
# 25090                             1                         0
# 18617                             1                         0
# 8482                              1                         0
# 1544                              0                         0
# ...                             ...                       ...
# 5699                              1                         0
# 10742                             0                         0
# 16921                             0                         0
# 25796                             0                         0
# 28847                             0                         0
#
#        marital-status_Widowed
# 22659                       0
# 25090                       0
# 18617                       0
# 8482                        0
# 1544                        0
# ...                       ...
# 5699                        0
# 10742                       0
# 16921                       0
# 25796                       0
# 28847                       0
#
# [24420 rows x 6 columns]
